# %%
# Using ?
b= [1,2,3,4]
b?
# Out:
# Type:        list
# String form: [1, 2, 3, 4]
# Length:      4
# Docstring:
# Built-in mutable sequence.
#
# If no argument is given, the constructor creates a new empty list.
# The argument must be an iterable if specified.

# %%
print?
# Out:
# Docstring:
# print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
# Prints the values to a stream, or to sys.stdout by default.
# Optional keyword arguments:
# file:  a file-like object (stream); defaults to the current sys.stdout.
# sep:   string inserted between values, default a space.
# end:   string appended after the last value, default a newline.
# flush: whether to forcibly flush the stream.
# Type:      builtin_function_or_method

# %%
for i in range(1,10):
    print(i, ',', flush = True)
# Out:
# 1 ,
# 2 ,
# 3 ,
# 4 ,
# 5 ,
# 6 ,
# 7 ,
# 8 ,
# 9 ,

# %% [markdown]
# # If you set flush=True when using the print function, it forces the output to be immediately flushed to the console, ensuring that the text appears right away.

# %%
def add(a,b,c):
    """add three numbers together
    Returns
    -------
    
    the sum of the arguments"""
    return a+b+c

# %%
add?
# Out:
# Signature: add(a, b, c)
# Docstring:
# add three numbers together
# Returns
# -------
#
# the sum of the arguments
# File:      /var/folders/jm/7qcz1nys2_l6rk66dc2f48wc0000gn/T/ipykernel_12555/415614350.py
# Type:      function

# %%
add??
# Out:
# Signature: add(a, b, c)
# Source:
# def add(a,b,c):
#     """add three numbers together
#     Returns
#     -------
#
#     the sum of the arguments"""
#     return a+b+c
# File:      /var/folders/jm/7qcz1nys2_l6rk66dc2f48wc0000gn/T/ipykernel_12555/415614350.py
# Type:      function

# %% [markdown]
# Finding names matching.

# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
np.*load*?
# Out:
# np.__loader__
# np.load
# np.loadtxt

# %%
def add(x,y,z):
    return x+y-z

# %%
# %run test_script.py

# %%
result
# Out:
# 10

# %%
y =100
result
# Out:
# 10

# %%
y
# Out:
# 100

# %%
# %run test_script.py

# %%
y
# Out:
# 3

# %% [markdown]
# %paste - No need in frontend

# %% [markdown]
# About Magic Commands

# %%
a = np.random.randn(10,10)
a
# Out:
# array([[-0.88746042, -1.48346551, -0.49936175,  2.30659362, -0.83492404,
#          0.02968657,  0.91236514, -0.19926438, -0.58887094, -0.14363464],
#        [ 1.41446398,  1.26307212,  1.56271929,  2.01400121,  1.1949093 ,
#         -0.89545729,  0.2857102 , -0.16239022, -0.65231542,  1.13359851],
#        [ 0.45065243, -0.88456525,  0.09661336,  0.19049836,  0.13324058,
#          0.3687439 ,  0.64158398, -0.00632293, -0.74573355, -0.17947884],
#        [-0.22242933,  1.35445528,  1.25495775, -1.17935773, -0.84310234,
#          0.1598823 ,  1.09597118, -1.1521192 ,  1.38816985,  0.06862019],
#        [-0.40234564, -0.19630596, -1.87117428, -0.52725061, -0.30251572,
#          1.06274628,  0.87053625,  1.19198586, -1.11021915,  1.10788287],
#        [-0.58922811, -2.0253309 ,  1.09810868,  0.84635953,  0.29392986,
#         -0.55456493, -1.69833602,  1.00400064,  0.57291443,  1.55011381],
#        [ 0.14547737, -0.92279613, -0.29067662, -0.71956141,  1.77758397,
# ...

# %%
# %timeit np.dot(a,a)
# Out:
# 532 ns ± 0.928 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# %timeit?
# Out:
# Docstring:
# Time execution of a Python statement or expression
#
# Usage, in line mode:
#   %timeit [-n<N> -r<R> [-t|-c] -q -p<P> -o] statement
# or in cell mode:
#   %%timeit [-n<N> -r<R> [-t|-c] -q -p<P> -o] setup_code
#   code
#   code...
#
# Time execution of a Python statement or expression using the timeit
# module.  This function can be used both as a line and cell magic:
#
# - In line mode you can time a single-line statement (though multiple
#   ones can be chained with using semicolons).
#
# - In cell mode, the statement in the first line is used as setup code
#   (executed but not timed) and the body of the cell is timed.  The cell
#   body has access to any variables created in the setup code.
#
# Options:
# -n<N>: execute the given statement <N> times in a loop. If <N> is not
# provided, <N> is determined so as to get sufficient accuracy.
#
# -r<R>: number of repeats <R>, each consisting of <N> loops, and take the
# average result.
# Default: 7
#
# ...

# %%
# %debug?
# Out:
# Docstring:
# ::
#
#   %debug [--breakpoint FILE:LINE] [statement ...]
#
# Activate the interactive debugger.
#
# This magic command support two ways of activating debugger.
# One is to activate debugger before executing code.  This way, you
# can set a break point, to step through the code from the point.
# You can use this mode by giving statements to execute and optionally
# a breakpoint.
#
# The other one is to activate debugger in post-mortem mode.  You can
# activate this mode simply running %debug without any argument.
# If an exception has just occurred, this lets you inspect its stack
# frames interactively.  Note that this will always work only on the last
# traceback that occurred, so you must call this quickly after an
# exception that you wish to inspect has fired, because if another one
# occurs, it clobbers the previous one.
#
# If you want IPython to automatically do this on every exception, see
# the %pdb magic for more details.
#
# .. versionchanged:: 7.3
# ...

# %%
pwd
# Out:
# '/Users/saurabhverma/Documents/GitHub/My_python_journey/Assignment_1/Python for Data Analysis by Wes mikkney'

# %%
who
# Out:
# a	 add	 b	 i	 np	 result	 x	 y	 z

# %%
whos
# Out:
# Variable   Type        Data/Info
# --------------------------------
# a          ndarray     10x10: 100 elems, type `float64`, 800 bytes
# add        function    <function add at 0x10c4e83a0>
# b          list        n=4
# i          int         9
# np         module      <module 'numpy' from '/Us<...>kages/numpy/__init__.py'>
# result     int         10
# x          int         1
# y          int         3
# z          int         6

# %% [markdown]
# ![Screenshot 2024-02-06 at 11.37.21 AM.png](<attachment:Screenshot 2024-02-06 at 11.37.21 AM.png>)

# %% [markdown]
# 2.3 Python Language Basics

# %%
#everything is an object
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 2
#       1 #everything is an object
# ----> 2 g()
#
# NameError: name 'g' is not defined

# %%
a = [1,2,3,4,5]
b=a
a.append(6)
b
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
isinstance(5, str)
# Out:
# False

# %%
#DUCK TYPING

# %%
import test_pi

# %%
pi= test_pi.PI

# %%
pi
# Out:
# 3.14159

# %%
test_pi.f(8)
# Out:
# 10

# %%
a is b
# Out:
# True

# %% [markdown]
# Most objects in python are mutable. Strings and tuple are immutable

# %%
s= r'This\has\many\backslashes'
s
# Out:
# 'This\\has\\many\\backslashes'

# %%
print(s)
# Out:
# This\has\many\backslashes

# %% [markdown]
# String Templating

# %%
template = '{0: .2f} {1:s} are worth US${2:d}'

# %%
template.format(5.44,'Argentina Pesos', 1)
# Out:
# ' 5.44 Argentina Pesos are worth US$1'

# %% [markdown]
# DAte and Time

# %% [markdown]
# from datetime import datetime, date, time

# %%
from datetime import datetime, date, time

# %%
dt= datetime.now()
dt
# Out:
# datetime.datetime(2024, 2, 7, 11, 51, 35, 43155)

# %%
dt.day
# Out:
# 7

# %%
dt.minute
# Out:
# 51

# %%
dt.time()
# Out:
# datetime.time(11, 51, 35, 43155)

# %%
dt.strftime('%m/%d/%Y %H:%M')
# Out:
# '02/07/2024 11:51'

# %% [markdown]
# ![image.png](attachment:image.png)
